# %% [markdown]
# Impoting Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading Dataset

# %%
data=pd.read_csv("/content/Heart Disease Dataset.zip")

# %% [markdown]
# Checking Dataset

# %%
data
# Out:
#      age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0     70     1                4                     130                322
# 1     67     0                3                     115                564
# 2     57     1                2                     124                261
# 3     64     1                4                     128                263
# 4     74     0                2                     120                269
# ..   ...   ...              ...                     ...                ...
# 265   52     1                3                     172                199
# 266   44     1                2                     120                263
# 267   56     0                2                     140                294
# 268   57     1                4                     140                192
# 269   67     1                4                     160                286
#
#      fasting blood sugar  resting electrocardiographic results  \
# ...

# %% [markdown]
# Checking datatypes

# %%
data.dtypes
# Out:
# age                                       int64
# sex                                       int64
# chest pain type                           int64
# resting blood pressure                    int64
# serum cholestoral                         int64
# fasting blood sugar                       int64
# resting electrocardiographic results      int64
# max heart rate                            int64
# exercise induced angina                   int64
# oldpeak                                 float64
# ST segment                                int64
# major vessels                             int64
# thal                                      int64
# heart disease                             int64
# dtype: object

# %% [markdown]
# Converting Datatypes

# %%
data['chest pain type']=data['chest pain type'].astype('category')
data['fasting blood sugar']=data['fasting blood sugar'].astype('category')
data['resting electrocardiographic results']=data['resting electrocardiographic results'].astype('category')
data['exercise induced angina']=data['exercise induced angina'].astype('category')
data['oldpeak']=data['oldpeak'].astype('category')
data['ST segment']=data['ST segment'].astype('category')
data['major vessels']=data['major vessels'].astype('category')
data['thal']=data['thal'].astype('category')
data['heart disease']=data['heart disease'].astype('category')

# %%
data.dtypes
# Out:
# age                                        int64
# sex                                        int64
# chest pain type                         category
# resting blood pressure                     int64
# serum cholestoral                          int64
# fasting blood sugar                     category
# resting electrocardiographic results    category
# max heart rate                             int64
# exercise induced angina                 category
# oldpeak                                 category
# ST segment                              category
# major vessels                           category
# thal                                    category
# heart disease                           category
# dtype: object

# %% [markdown]
# Coverting Sex to categorical is showing Error..First coverting to object then to categorical is option

# %%
data
# Out:
#      age  sex  chest pain type  resting blood pressure  serum cholestoral  \
# 0     70     1               4                     130                322
# 1     67     0               3                     115                564
# 2     57     1               2                     124                261
# 3     64     1               4                     128                263
# 4     74     0               2                     120                269
# ..   ...   ...             ...                     ...                ...
# 265   52     1               3                     172                199
# 266   44     1               2                     120                263
# 267   56     0               2                     140                294
# 268   57     1               4                     140                192
# 269   67     1               4                     160                286
#
#     fasting blood sugar resting electrocardiographic results  max heart rate  \
# ...

# %% [markdown]
# Unable to convert sex column to categorical data..going with further steps

# %% [markdown]
# Checking Duplicates

# %%
data[data.duplicated()].shape
# Out:
# (0, 14)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, sex , chest pain type, resting blood pressure, serum cholestoral, fasting blood sugar, resting electrocardiographic results, max heart rate, exercise induced angina, oldpeak, ST segment, major vessels, thal, heart disease]
# Index: []

# %% [markdown]
# Renaming Columns

# %%
data.rename(columns={
    'chest pain type': 'chest_pain_type',
    'resting blood pressure': 'resting_bp',
    'serum cholestoral': 'cholesterol',
    'resting electrocardiographic results': 'rest_ecg',
    'max heart rate': 'max_hr',
    'exercise induced angina': 'exercise_angina',
    'ST segment': 'st_segment',
    'major vessels': 'num_vessels',
    'thal': 'thalassemia',
    'heart disease': 'heart_disease'
}, inplace=True)

# %%
data
# Out:
#      age  sex  chest_pain_type  resting_bp  cholesterol fasting blood sugar  \
# 0     70     1               4         130          322                   0
# 1     67     0               3         115          564                   0
# 2     57     1               2         124          261                   0
# 3     64     1               4         128          263                   0
# 4     74     0               2         120          269                   0
# ..   ...   ...             ...         ...          ...                 ...
# 265   52     1               3         172          199                   1
# 266   44     1               2         120          263                   0
# 267   56     0               2         140          294                   0
# 268   57     1               4         140          192                   0
# 269   67     1               4         160          286                   0
#
# ...

# %% [markdown]
# Checking Missing Values

# %%
data.isnull().sum()
# Out:
# age                    0
# sex                    0
# chest_pain_type        0
# resting_bp             0
# cholesterol            0
# fasting blood sugar    0
# rest_ecg               0
# max_hr                 0
# exercise_angina        0
# oldpeak                0
# st_segment             0
# num_vessels            0
# thalassemia            0
# heart_disease          0
# dtype: int64

# %% [markdown]
# Checking Outliers in target variable using Histogram and Boxplot

# %%
data['heart_disease'].hist()
# Out:
# <Axes: >

# %%
data_box=data.heart_disease

# %%
plt.boxplot(data_box)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x79214bbd39d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x79214bbd12a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x79214bbd0ca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x79214bbd2650>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79214b7a60b0>],
#  'means': []}

# %% [markdown]
# No Outliers are found

# %% [markdown]
# Checking Data using Descriptive statistics

# %%
data.describe()
# Out:
#               age        sex   resting_bp  cholesterol      max_hr
# count  270.000000  270.000000  270.000000   270.000000  270.000000
# mean    54.433333    0.677778  131.344444   249.659259  149.677778
# std      9.109067    0.468195   17.861608    51.686237   23.165717
# min     29.000000    0.000000   94.000000   126.000000   71.000000
# 25%     48.000000    0.000000  120.000000   213.000000  133.000000
# 50%     55.000000    1.000000  130.000000   245.000000  153.500000
# 75%     61.000000    1.000000  140.000000   280.000000  166.000000
# max     77.000000    1.000000  200.000000   564.000000  202.000000

# %% [markdown]
# Using Scatter Plot and Correlation to check relation between Feature cariables

# %%
sns.pairplot(data)

# %%
data.corr()
# Out:
#                           age      sex   chest_pain_type  resting_bp  \
# age                  1.000000 -0.094401         0.096920    0.273053
# sex                 -0.094401  1.000000         0.034636   -0.062693
# chest_pain_type      0.096920  0.034636         1.000000   -0.043196
# resting_bp           0.273053 -0.062693        -0.043196    1.000000
# cholesterol          0.220056 -0.201647         0.090465    0.173019
# fasting blood sugar  0.123458  0.042140        -0.098537    0.155681
# rest_ecg             0.128171  0.039253         0.074325    0.116157
# max_hr              -0.402215 -0.076101        -0.317682   -0.039136
# exercise_angina      0.098297  0.180022         0.353160    0.082793
# oldpeak              0.194234  0.097412         0.167244    0.222800
# st_segment           0.159774  0.050545         0.136900    0.142472
# num_vessels          0.356081  0.086830         0.225890    0.085697
# thalassemia          0.106100  0.391046         0.262659    0.132045
# ...

# %% [markdown]
# In the above context we can observe if there is strong correlation the value will be 1 or 0.8
